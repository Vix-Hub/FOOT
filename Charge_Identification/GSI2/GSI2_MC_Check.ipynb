# %% [markdown]
# # Import

# %%
import ROOT as r
import fedrarootlogon 
from matplotlib import pyplot as plt
import matplotlib
import awkward as ak
import uproot
import numpy as np
import time

import sys
sys.path.insert(0, "/home/vincenzo/Documents/Vincenzo_FOOT/")
from Clustering_Cosmici_Frammenti import *

def g_func(x, p1, p2, p3):
    return p1* np.exp(- (x - p2)**2 / (2*p3**2) )

# %jsroot on 
track_name = "b000002.2.0.0.trk.root"
file_name = "~/Documents/Vincenzo_FOOT/b22_MC.root"
brick_id = "GSI2"

# %% [markdown]
# # Calcolo Variabili di Volume

# %%
#Calcolo_Variabili_Volume_MC(file_name, track_name)
# Out:
# 1

# %% [markdown]
# # Taglio su k0, Plot VR0 vs tan

# %% [markdown]
# ### Analisi per k0

# %%
file = r.TFile(file_name, "READ")
tracks_V = file.Get("tracks_n")

c = r.TCanvas()
tracks_V.Draw("k0", "npl>=32")
t1 = r.TText(c.GetUxmax()/2, 500, brick_id)
t1.SetTextColor(1)
t1.SetTextSize(20)
t1.Draw("SAME")
c.Draw()
# Out:
# <div id="root_plot_1664440076428"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664440076428(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0.99999992549419,"fY1":-571.331292567498,"fX2":11.0000000745058,"fY2":5141.9812925675,"fXtoAbsPixelk":-69.5999437772748,"fXtoPixelk":-69.5999437772748,"fXtoPixel":69.5999989628791,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.0826140689777868,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":0.99999992549419,"fPixeltoXk":0.99999992549419,"fPixeltoX":0.0143678163060512,"fAbsPixeltoYk":5141.9812925675,"fPixeltoYk":-571.331292567498,"fPixeltoY":-12.104475815964,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":2,"fUymin":0,"fUxmax":10,"fUymax":4570.65,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":2,"fY1":0,"fX2":10,"fY2":4570.65,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":9,"fName":"htemp","fTitle":"k0 {npl>=32}","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":10,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":4194304,"fName":"xaxis","fTitle":"k0","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":8,"fXmin":2,"fXmax":10,"fXbins":[],"fFirst":1,"fLast":100,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":11089,"fTsumw":11089,"fTsumw2":11089,"fTsumwx":89734,"fTsumwx2":735072,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":8.8000002026558,"fY1":3856.48599496612,"fX2":10.8000002622604,"fY2":4770.61598815532,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC","fName":"stats","fTextAngle":0,"fTextSize":0,"fTextAlign":12,"fTextColor":1,"fTextFont":4 ...

# %%
file = r.TFile(file_name, "READ")
tracks_V = file.Get("tracks_n")

c = r.TCanvas()
tracks_V.Draw("k1", "npl>=32")
t1 = r.TText(c.GetUxmax()/2, 500, brick_id)
t1.SetTextColor(1)
t1.SetTextSize(20)
t1.Draw("SAME")
c.Draw()

# %%
c = r.TCanvas()

tracks_V.Draw("tanf>>Z1(100, 0, 1)", "s[0].W()-70 == 1 && k0>=4")
hs = r.THStack("h4s", "")
h1 = r.gDirectory.Get("Z1")
hs.Add(h1)

tracks_V.Draw("tanf>>Z2(100, 0, 1)", "s[0].W()-70 == 2 && k0>=4")
h2 = r.gDirectory.Get("Z2")
hs.Add(h2)

tracks_V.Draw("tanf>>Z3(100, 0, 1)", "s[0].W()-70 == 3 && k0>=4")
h3 = r.gDirectory.Get("Z3")
hs.Add(h3)

tracks_V.Draw("tanf>>Z4(100, 0, 1)", "s[0].W()-70 == 4 && k0>=4")
h4 = r.gDirectory.Get("Z4")
hs.Add(h4)

# %%
c = r.TCanvas()
h4.Draw()
c.Draw()

# %%
hs.SetTitle("Fragments Angular Distribution GSI3 MC_{rec} (k_{0}>=4); tan(#theta); Entries")
hs.Draw("pfc nostack")

legend = r.TLegend(0.55,0.6,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(0.1)

def lazy(histo, N):
    return "Entries = "+str(histo.GetEntries()) + " (" + str(round(100*histo.GetEntries()/N, 1)) + "%)}{Mean: "+ str(round(histo.GetMean(), 2)) + ", RMS = "+str(round(histo.GetRMS(),2))+"}"

legend.AddEntry(h1, "#splitline{Z=1, " + lazy(h1, 70965))
legend.AddEntry(h2, "#splitline{Z=2, "+ lazy(h2, 70965))
legend.AddEntry(h3, "#splitline{Z=3, "+ lazy(h3, 70965))
legend.AddEntry(h4, "#splitline{Z==4, "+ lazy(h4, 70965))
legend.Draw("SAME")

c.Draw()

# %%
c = r.TCanvas()

tracks_V.Draw("tanf>>Z1(100, 0, 1)", "s[0].W()-70 == 1 && k0>=3")
hs = r.THStack("h4s", "")
h1 = r.gDirectory.Get("Z1")
hs.Add(h1)

tracks_V.Draw("tanf>>Z2(100, 0, 1)", "s[0].W()-70 == 2 && k0>=3")
h2 = r.gDirectory.Get("Z2")
hs.Add(h2)

tracks_V.Draw("tanf>>Z3(100, 0, 1)", "s[0].W()-70 == 3 && k0>=3")
h3 = r.gDirectory.Get("Z3")
hs.Add(h3)

tracks_V.Draw("tanf>>Z4(100, 0, 1)", "s[0].W()-70 == 4 && k0>=3")
h4 = r.gDirectory.Get("Z4")
hs.Add(h4)

# %%
hs.SetTitle("Fragments Angular Distribution GSI3 MC (k_{0}>=3); tan(#theta); Entries")
hs.Draw("pfc nostack")

legend = r.TLegend(0.55,0.6,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(0.1)

def lazy(histo):
    return "Entries = "+str(histo.GetEntries())+"}{Mean: "+ str(round(histo.GetMean(), 2)) + ", RMS = "+str(round(histo.GetRMS(),2))+"}"

legend.AddEntry(h1, "#splitline{Z=1, " + lazy(h1))
legend.AddEntry(h2, "#splitline{Z=2, "+ lazy(h2))
legend.AddEntry(h3, "#splitline{Z=3, "+ lazy(h3))
legend.AddEntry(h4, "#splitline{Z==4, "+ lazy(h4))
legend.Draw("SAME")

c.Draw()

# %%
c = r.TCanvas()
tracks_V.Draw("tan", "s[0].W()-70 == 8")
c.Draw()

# %%
c = r.TCanvas()
tracks_V.Draw("tan", "s[0].W()-70 == 1 && tan<1 ")
c.Draw()

# %%
c = r.TCanvas()
tracks_V.Draw("sf.P()", "s[0].W()-70 == 1 && tan<1")
c.Draw()

# %% [markdown]
# ## Controlli

# %%
c = r.TCanvas()

tracks_V.Draw("tanf>>Z1(100, 0, 1)", "s[0].W()-70 == 1 && k0>=4")
hs = r.THStack("h4s", "")
h1 = r.gDirectory.Get("Z1")
hs.Add(h1)

tracks_V.Draw("tanf>>Z2(100, 0, 1)", "s[0].W()-70 == 2 && k0>=4")
h2 = r.gDirectory.Get("Z2")
hs.Add(h2)

tracks_V.Draw("tanf>>Z3(100, 0, 1)", "s[0].W()-70 == 3 && k0>=4")
h3 = r.gDirectory.Get("Z3")
hs.Add(h3)

tracks_V.Draw("tanf>>Z4(100, 0, 1)", "s[0].W()-70 == 4 && k0>=4")
h4 = r.gDirectory.Get("Z4")
hs.Add(h4)

tracks_V.Draw("tanf>>Z5(100, 0, 1)", "s[0].W()-70 == 5 && k0>=4")
h5 = r.gDirectory.Get("Z5")
hs.Add(h5)

tracks_V.Draw("tanf>>Z6(100, 0, 1)", "s[0].W()-70 == 6 && k0>=4")
h6 = r.gDirectory.Get("Z6")
hs.Add(h6)

tracks_V.Draw("tanf>>Z7(100, 0, 1)", "s[0].W()-70 == 7 && k0>=4")
h7 = r.gDirectory.Get("Z7")
hs.Add(h7)

tracks_V.Draw("tanf>>Z8(100, 0, 1)", "s[0].W()-70 == 8 && k0>=4")
h8 = r.gDirectory.Get("Z8")
#hs.Add(h8)

# %%
hs.SetTitle("Fragments Angular Distribution GSI3 MC_{rec} (k_{0}>=4); tan(#theta); Entries")
hs.Draw("pfc nostack")

legend = r.TLegend(0.55,0.6,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(0.1)

N = h1.GetEntries() + h2.GetEntries() + h3.GetEntries() + h4.GetEntries()
N = N + h5.GetEntries() + h6.GetEntries() + h7.GetEntries() + h8.GetEntries()

def lazy(histo, N):
    return "Entries = "+str(histo.GetEntries()) + " (" + str(round(100*histo.GetEntries()/N, 1)) + "%)}{Mean: "+ str(round(histo.GetMean(), 2)) + ", RMS = "+str(round(histo.GetRMS(),2))+"}"

legend.AddEntry(h1, "#splitline{Z=1, " + lazy(h1, N))
legend.AddEntry(h2, "#splitline{Z=2, "+ lazy(h2, N))
legend.AddEntry(h3, "#splitline{Z=3, "+ lazy(h3, N))
legend.AddEntry(h4, "#splitline{Z=4, "+ lazy(h4, N))
legend.AddEntry(h5, "#splitline{Z=5, " + lazy(h5, N))
legend.AddEntry(h6, "#splitline{Z=6, "+ lazy(h6, N))
legend.AddEntry(h7, "#splitline{Z=7, "+ lazy(h7, N))
#legend.AddEntry(h8, "#splitline{Z=8, "+ lazy(h8, N))
legend.Draw("SAME")

c.Draw()

# %%
print(N)

# %%
c = r.TCanvas()
h2.SetTitle("Z = 2 Angular Distribution (MC_{rec});tan(#theta);Entries")
h2.SetFillColor(0)
h2.SetLineColor(4)
h2.SetLineWidth(2)
h2.Draw()
c.Draw()

# %%
c = r.TCanvas()
h2.SetTitle("Z = 2 Angular Distribution (MC_{rec});tan(#theta);Entries")
h2.Scale(1./h2.GetEntries())
h2.Draw()
c.Draw()

# %%
c = r.TCanvas()

tracks_V.Draw("tanf>>Z1(100, 0, 1)", "s[0].W()-70 == 1 && k0>=1")
hs = r.THStack("h4s", "")
h1 = r.gDirectory.Get("Z1")
hs.Add(h1)

tracks_V.Draw("tanf>>Z2(100, 0, 1)", "s[0].W()-70 == 2 && k0>=1")
h2 = r.gDirectory.Get("Z2")
hs.Add(h2)

tracks_V.Draw("tanf>>Z3(100, 0, 1)", "s[0].W()-70 == 3 && k0>=1")
h3 = r.gDirectory.Get("Z3")
hs.Add(h3)

tracks_V.Draw("tanf>>Z4(100, 0, 1)", "s[0].W()-70 == 4 && k0>=1")
h4 = r.gDirectory.Get("Z4")
hs.Add(h4)

tracks_V.Draw("tanf>>Z5(100, 0, 1)", "s[0].W()-70 == 5 && k0>=1")
h5 = r.gDirectory.Get("Z5")
hs.Add(h5)

tracks_V.Draw("tanf>>Z6(100, 0, 1)", "s[0].W()-70 == 6 && k0>=1")
h6 = r.gDirectory.Get("Z6")
hs.Add(h6)

tracks_V.Draw("tanf>>Z7(100, 0, 1)", "s[0].W()-70 == 7 && k0>=1")
h7 = r.gDirectory.Get("Z7")
hs.Add(h7)

tracks_V.Draw("tanf>>Z8(100, 0, 1)", "s[0].W()-70 == 8 && k0>=1")
h8 = r.gDirectory.Get("Z8")
hs.Add(h8)

# %%
hs.SetTitle("Fragments Angular Distribution GSI3 MC_{rec} (k_{0}>=1); tan(#theta); Entries")
hs.Draw("pfc nostack")

legend = r.TLegend(0.55,0.6,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(0.1)

N = h1.GetEntries() + h2.GetEntries() + h3.GetEntries() + h4.GetEntries()
N = N + h5.GetEntries() + h6.GetEntries() + h7.GetEntries() + h8.GetEntries()

def lazy(histo, N):
    return "Entries = "+str(histo.GetEntries()) + " (" + str(round(100*histo.GetEntries()/N, 1)) + "%)}{Mean: "+ str(round(histo.GetMean(), 2)) + ", RMS = "+str(round(histo.GetRMS(),2))+"}"

legend.AddEntry(h1, "#splitline{Z=1, " + lazy(h1, N))
legend.AddEntry(h2, "#splitline{Z=2, "+ lazy(h2, N))
legend.AddEntry(h3, "#splitline{Z=3, "+ lazy(h3, N))
legend.AddEntry(h4, "#splitline{Z=4, "+ lazy(h4, N))
legend.AddEntry(h5, "#splitline{Z=5, " + lazy(h5, N))
legend.AddEntry(h6, "#splitline{Z=6, "+ lazy(h6, N))
legend.AddEntry(h7, "#splitline{Z=7, "+ lazy(h7, N))
legend.AddEntry(h8, "#splitline{Z=8, "+ lazy(h8, N))
legend.Draw("SAME")

c.Draw()

# %%
c = r.TCanvas()

tracks_V.Draw("tanf>>Z1(100, 0, 1)", "s[0].W()-70 == 1 && k0>=4")
hs = r.THStack("h4s", "")
h1 = r.gDirectory.Get("Z1")
hs.Add(h1)

tracks_V.Draw("tanf>>Z2(100, 0, 1)", "s[0].W()-70 == 2 && k0>=4")
h2 = r.gDirectory.Get("Z2")
hs.Add(h2)

tracks_V.Draw("tanf>>Z3(100, 0, 1)", "s[0].W()-70 == 3 && k0>=4")
h3 = r.gDirectory.Get("Z3")
hs.Add(h3)

tracks_V.Draw("tanf>>Z4(100, 0, 1)", "s[0].W()-70 == 4 && k0>=4")
h4 = r.gDirectory.Get("Z4")
hs.Add(h4)

tracks_V.Draw("tanf>>Z5(100, 0, 1)", "s[0].W()-70 == 5 && k0>=4")
h5 = r.gDirectory.Get("Z5")
hs.Add(h5)

tracks_V.Draw("tanf>>Z6(100, 0, 1)", "s[0].W()-70 == 6 && k0>=4")
h6 = r.gDirectory.Get("Z6")
hs.Add(h6)

tracks_V.Draw("tanf>>Z7(100, 0, 1)", "s[0].W()-70 == 7 && k0>=4")
h7 = r.gDirectory.Get("Z7")
hs.Add(h7)

tracks_V.Draw("tanf>>Z8(100, 0, 1)", "s[0].W()-70 == 8 && k0>=4")
h8 = r.gDirectory.Get("Z8")
hs.Add(h8)

# %%
hs.SetTitle("Fragments Angular Distribution GSI3 MC_{rec} (k_{0}>=4); tan(#theta); Entries")
hs.Draw("pfc nostack")

legend = r.TLegend(0.55,0.6,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(0.1)

N = h1.GetEntries() + h2.GetEntries() + h3.GetEntries() + h4.GetEntries()
N = N + h5.GetEntries() + h6.GetEntries() + h7.GetEntries() + h8.GetEntries()

def lazy(histo, N):
    return "Entries = "+str(histo.GetEntries()) + " (" + str(round(100*histo.GetEntries()/N, 1)) + "%)}{Mean: "+ str(round(histo.GetMean(), 2)) + ", RMS = "+str(round(histo.GetRMS(),2))+"}"

legend.AddEntry(h1, "#splitline{Z=1, " + lazy(h1, N))
legend.AddEntry(h2, "#splitline{Z=2, "+ lazy(h2, N))
legend.AddEntry(h3, "#splitline{Z=3, "+ lazy(h3, N))
legend.AddEntry(h4, "#splitline{Z=4, "+ lazy(h4, N))
legend.AddEntry(h5, "#splitline{Z=5, " + lazy(h5, N))
legend.AddEntry(h6, "#splitline{Z=6, "+ lazy(h6, N))
legend.AddEntry(h7, "#splitline{Z=7, "+ lazy(h7, N))
legend.AddEntry(h8, "#splitline{Z=8, "+ lazy(h8, N))
legend.Draw("SAME")

c.Draw()

# %%
N

# %% [markdown]
# # Confronti con Output

# %%
out_name = "output_cuts_GSI2.root"
file_out = r.TFile(out_name, "READ")

out_tree = file_out.Get("tracks")

out_tree.Draw("s[0].Theta()>>o1(100,0,1)", "Z==1")
o1 = r.gDirectory.Get("o1")

c = r.TCanvas()
#o1.Scale(1/o1.Integral())
o1.Draw()
o1.Sumw2()
c.Draw()
# Out:
# Warning in <TFile::Init>: file output_cuts_GSI2.root probably not closed, trying to recover
# Info in <TFile::Recover>: output_cuts_GSI2.root, recovered key TTree:tracks at address 99839114
# Info in <TFile::Recover>: output_cuts_GSI2.root, recovered key TTree:output_tree at address 108686888
# Warning in <TFile::Init>: successfully recovered 2 keys
# <div id="root_plot_1664440086442"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664440086442(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.125000009313226,"fY1":-72.0476834150303,"fX2":1.12500000931323,"fY2":648.429107791508,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":556.799991703033,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.655121727390511,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.125000009313226,"fPixeltoXk":-0.125000009313226,"fPixeltoX":0.0017959770382564,"fAbsPixeltoYk":648.429107791508,"fPixeltoYk":-72.0476834150303,"fPixeltoY":-1.52643387967487,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":576.381424376477,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":1,"fY2":576.381424376477,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"o1","fTitle":"s[0].Theta() {Z==1}","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":18717,"fTsumw":18699,"fTsumw2":18699,"fTsumwx":5869.32891776902,"fTsumwx2":2786.83145494474,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,32,113,167,223,290,336,388,438,441,422,447,459,526,482,477,453,426,464,469,457,342,380,377,342,352,344,358,310,297,290,242,246,247,237,242,261,226,224,170,198,196,194,171,195,169,184,171,169,151,147,147,136,147,134,128,122,121,114,116,96,100,104,106,102,107,86,94,91,85,89,98,79,62,67,75,87,65,66,59,60,57,61,56,53,49,41,37,56,41,44,37,35,38,48,39,35,29,30,16,12,18],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWid ...

# %%
out_tree.Draw("nseg>>Z5(50)", "Z>0 && Z<7")
h4 = r.gDirectory.Get("Z5")
N2 = h4.GetEntries()
print(N2)


tracks_V.Draw("tanf>>N(100, 0, 1)", "s[0].W()-70 > 0 && k0>=1")
h8 = r.gDirectory.Get("N")
N = h8.GetEntries()
print(N)
# Out:
# 26316.0
# 25328.0

# %%
h1.SetFillColor(0)
h1.SetLineColor(2)
h1.SetLineWidth(2)
h1.Sumw2(r.kFALSE)

o1.SetFillColor(0)
o1.SetLineColor(4)
o1.SetLineWidth(2)
o1.Sumw2(r.kFALSE)

h1.Scale(1/N)
o1.Scale(1/N2)

s1 = r.THStack("s1", "s1")
s1.Add(o1)
s1.Add(h1)
c = r.TCanvas()
s1.SetTitle("MC_{rec} vs Data [k_{0}>=1, Z=1];tan(#theta);Entries/N_{trk}")
s1.Draw("nostack")

legend = r.TLegend(0.45,0.65,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(1.)
legend.AddEntry(h1, "#splitline{Z=1 (MC_{rec}), Entries = "+str(round(h1.GetEntries(),0))+" ("+str(round(100*h1.GetEntries()/N, 1) ) + " %)}{Mean: "+ str(round(h1.GetMean(), 2)) + ", RMS = "+str(round(h1.GetRMS(),2))+"}")
legend.AddEntry(o1, "#splitline{Z=1 (Data), Entries = "+str(round(o1.GetEntries(),0))+" ("+str(round(100*o1.GetEntries()/N2, 1) ) + " %)}{Mean: "+ str(round(o1.GetMean(), 2)) + ", RMS = "+str(round(o1.GetRMS(),2))+"}")

legend.Draw("SAME")

c.Draw()

# %%
N

# %%
h1.Scale(1/N)
o1.Scale(1/N2)

# %%
c = r.TCanvas()
#o1.Draw()
h1.Draw("SAME")
c.Draw()

# %%
c = r.TCanvas()
o1.Draw()
#h1.Draw("SAME")
c.Draw()

# %%
h1.SetFillColor(0)
h1.SetLineColor(2)
h1.SetLineWidth(2)
h1.Sumw2(r.kFALSE)

o1.SetFillColor(0)
o1.SetLineColor(4)
o1.SetLineWidth(2)
o1.Sumw2(r.kFALSE)

s1 = r.THStack("s1", "s1")
s1.Add(o1)
s1.Add(h1)
c = r.TCanvas()
s1.SetTitle("MC_{rec} vs Data [k_{0}>=4, Z=1];tan(#theta);Entries/N_{trk}")
s1.Draw("nostack")

legend = r.TLegend(0.45,0.65,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(1.)
legend.AddEntry(h1, "#splitline{Z=1 (MC_{rec}), Entries = "+str(round(h1.GetEntries(),0))+"}{Mean: "+ str(round(h1.GetMean(), 2)) + ", RMS = "+str(round(h1.GetRMS(),2))+"}")
legend.AddEntry(o1, "#splitline{Z=1 (Data), Entries = "+str(round(o1.GetEntries(),0))+"}{Mean: "+ str(round(o1.GetMean(), 2)) + ", RMS = "+str(round(o1.GetRMS(),2))+"}")

legend.Draw("SAME")

c.Draw()

# %%
N

# %%
def CompareMC2(Z, N, N2):
    
    if (Z!=6 and Z!=5 and Z!=4):
        out_tree.Draw("s[0].Theta()>>o"+str(Z)+"(50,0,1)", "Z=="+str(Z))
    elif (Z==6):
        out_tree.Draw("s[0].Theta()>>o"+str(Z)+"(50,0,0.1)", "Z=="+str(Z))
    elif (Z==5):
        out_tree.Draw("s[0].Theta()>>o"+str(Z)+"(50,0,0.2)", "Z=="+str(Z))
    elif (Z==4):
        out_tree.Draw("s[0].Theta()>>o"+str(Z)+"(50,0,0.2)", "Z=="+str(Z))
    o = r.gDirectory.Get("o"+str(Z))
    o.Scale(1/N2)
    o.Sumw2()
    
    if (Z!=6 and Z!=5 and Z!=4):
        print("tanf>>Z_"+str(Z)+"(100, 0, 1)", "s[0].W()-70 == "+str(Z)+" && k0>=4")
        tracks_V.Draw("s[0].Theta()>>Z_"+str(Z)+"(50, 0, 1)", "s[0].W()-70 == "+str(Z)+" && k0>=1")
    elif (Z == 6):
        tracks_V.Draw("s[0].Theta()>>Z_"+str(Z)+"(50, 0, 0.1)", "s[0].W()-70 >= "+str(Z)+" && s[0].W()-70<9 && k0>=1")
    elif (Z == 5):
        tracks_V.Draw("s[0].Theta()>>Z_"+str(Z)+"(50, 0, 0.2)", "s[0].W()-70 == "+str(Z)+" && s[0].W()-70<9 && k0>=1")
    elif (Z == 4):
        tracks_V.Draw("s[0].Theta()>>Z_"+str(Z)+"(50, 0, 0.2)", "s[0].W()-70 >= "+str(Z)+" && s[0].W()-70<9 && k0>=1")
    h = r.gDirectory.Get("Z_"+str(Z))
    h.Scale(1/N)
    h.Sumw2(r.kFALSE)
    
    h.SetFillColor(0)
    h.SetLineColor(r.kBlue)
    
    h.SetLineWidth(2)
    h.SetLineStyle(2)

    o.SetFillColor(0)
    o.SetLineColor(r.kCyan-2)
    o.SetLineWidth(2)
    
    s = r.THStack("s", "s")
    s.Add(o)
    s.Add(h)
    
    s.SetTitle("MC_{rec} vs Data [k_{0}>=1, Z="+str(Z)+"];tan(#theta);Entries/N_{trk}")
    #s.Draw("nostack")

    legend = r.TLegend(0.45,0.65,0.9,0.9)
    legend.SetTextFont(0)
    legend.SetTextSize(1.)
    legend.AddEntry(h, "#splitline{Z="+str(Z)+" (MC_{rec}), Entries = "+str(round(h.GetEntries(),0))+" ("+str(round(100*h.GetEntries()/N, 1) ) + " %)}{Mean: "+ str(round(h.GetMean(), 2)) + ", RMS = "+str(round(h.GetRMS(),2))+"}")
    legend.AddEntry(o, "#splitline{Z="+str(Z)+ " (Data), Entries = "+str(round(o.GetEntries(),0))+" ("+str(round(100*o.GetEntries()/N2, 1) ) + " %)}{Mean: "+ str(round(o.GetMean(), 2)) + ", RMS = "+str(round(o.GetRMS(),2))+"}")

    return s, legend

# %%
s1, leg1 = CompareMC2(1,N,N2)
s2, leg2 = CompareMC2(2,N,N2)
s3, leg3 = CompareMC2(3,N,N2)
s4, leg4 = CompareMC2(4,N,N2)
# Out:
# tanf>>Z_1(100, 0, 1) s[0].W()-70 == 1 && k0>=4
# tanf>>Z_2(100, 0, 1) s[0].W()-70 == 2 && k0>=4
# tanf>>Z_3(100, 0, 1) s[0].W()-70 == 3 && k0>=4
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %%
c = r.TCanvas()
s1.Draw("nostack")
leg1.Draw("SAME")
c.Draw()
# Out:
# <div id="root_plot_1664440103562"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664440103562(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.125000009313226,"fY1":-0.00502735993563085,"fX2":1.12500000931323,"fY2":0.0452462364241376,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":556.799991703033,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-9388.62612139916,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.125000009313226,"fPixeltoXk":-0.125000009313226,"fPixeltoX":0.0017959770382564,"fAbsPixeltoYk":0.0452462364241376,"fPixeltoYk":-0.00502735993563085,"fPixeltoY":-1.06511856694425e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":0.0402188764885068,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":1,"fY2":0.0402188764885068,"fBorderSize":1,"fBorderMode":0},{"_typename":"THStack","fUniqueID":0,"fBits":8,"fName":"s","fTitle":"MC_{rec} vs Data [k_{0}>=1, Z=1];tan(#theta);Entries\/N_{trk}","fHists":{"_typename":"TList","name":"TList","arr":[{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"o1","fTitle":"s[0].Theta() {Z==1}","fLineColor":430,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":52,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":50,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":18717,"fTsumw":0.710556315549476,"fTsumw2":2.70009239834882e-5,"fTsumwx":0.223032714613506,"fTsumwx2":0.105898748097915,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,2.093766499602e-7,5.63150989548125e-7,9.03929537069555e-7,1.192724916325e-6,1.24615206148726e-6,1.30824306802718e-6,1.45552871144746e-6,1.34289851353784e-6,1.28513943768675e-6,1.33712260595273e-6,1.04255131911217e-6,1.03821938842334e-6,1.00500791980896e-6,9.645765667132e-7,8.47614438114743e-7,7.046 ...

# %%
c = r.TCanvas()
s2.Draw("nostack")
leg2.Draw("SAME")
c.Draw()
# Out:
# <div id="root_plot_1664440103691"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664440103691(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.125000009313226,"fY1":-0.0050161880453071,"fX2":1.12500000931323,"fY2":0.0451456894178829,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":556.799991703033,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-9409.53616312239,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.125000009313226,"fPixeltoXk":-0.125000009313226,"fPixeltoX":0.0017959770382564,"fAbsPixeltoYk":0.0451456894178829,"fPixeltoYk":-0.0050161880453071,"fPixeltoY":-1.06275164116928e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":0.0401295013725758,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":1,"fY2":0.0401295013725758,"fBorderSize":1,"fBorderMode":0},{"_typename":"THStack","fUniqueID":0,"fBits":8,"fName":"s","fTitle":"MC_{rec} vs Data [k_{0}>=1, Z=2];tan(#theta);Entries\/N_{trk}","fHists":{"_typename":"TList","name":"TList","arr":[{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"o2","fTitle":"s[0].Theta() {Z==2}","fLineColor":430,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":52,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":50,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":4612,"fTsumw":0.175254597963216,"fTsumw2":6.65962144563065e-6,"fTsumwx":0.0250279434996707,"fTsumwx2":0.00659155569554055,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,2.2526039581925e-7,6.22354042295493e-7,7.79747523989712e-7,8.40394553633356e-7,7.53755939856722e-7,6.67117326080087e-7,4.505207916385e-7,4.17309323024124e-7,2.91683333048003e-7,2.65691748915013e-7,2.02156765478814e-7,1.68945296864438e-7,1.28513943768675e-7,1.09742244117071e-7,7.79747523989712e-8,8. ...

# %%
c = r.TCanvas()
s3.Draw("nostack")
leg3.Draw("SAME")
c.Draw()
# Out:
# <div id="root_plot_1664440103804"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664440103804(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.125000009313226,"fY1":-0.00140646381188846,"fX2":1.12500000931323,"fY2":0.0126581734686784,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":556.799991703033,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-33559.343947829,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.125000009313226,"fPixeltoXk":-0.125000009313226,"fPixeltoX":0.0017959770382564,"fAbsPixeltoYk":0.0126581734686784,"fPixeltoYk":-0.00140646381188846,"fPixeltoY":-2.97979603401839e-5,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":0.0112517096567899,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":1,"fY2":0.0112517096567899,"fBorderSize":1,"fBorderMode":0},{"_typename":"THStack","fUniqueID":0,"fBits":8,"fName":"s","fTitle":"MC_{rec} vs Data [k_{0}>=1, Z=3];tan(#theta);Entries\/N_{trk}","fHists":{"_typename":"TList","name":"TList","arr":[{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"o3","fTitle":"s[0].Theta() {Z==3}","fLineColor":430,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":52,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":50,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":2199,"fTsumw":0.0835613315093479,"fTsumw2":3.17530519491366e-6,"fTsumwx":0.0100243440427187,"fTsumwx2":0.00189199327364092,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,8.66386137766347e-8,3.36446616832598e-7,3.86985808202302e-7,4.07201484750183e-7,3.85541831306024e-7,3.5088638579537e-7,2.61359818226181e-7,2.36812210989468e-7,1.50173597212833e-7,1.4150973583517e-7,9.24145213617437e-8,6.35349834361988e-8,7.0754867917585e-8,4.33193068883173e-8,2.02156765478814e-8, ...

# %%
c = r.TCanvas()
s4.Draw("nostack")
leg4.Draw("SAME")
c.Draw()
# Out:
# <div id="root_plot_1664440103916"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664440103916(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.0250000018626453,"fY1":-2.74646663546313e-4,"fX2":0.225000001862645,"fY2":0.00247181980821465,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":2783.99995851517,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-171857.186262086,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.0250000018626453,"fPixeltoXk":-0.0250000018626453,"fPixeltoX":3.59195407651279e-4,"fAbsPixeltoYk":0.00247181980821465,"fPixeltoYk":-2.74646663546313e-4,"fPixeltoY":-5.81878489779866e-6,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":0.2,"fUymax":0.00219717314466834,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":0.2,"fY2":0.00219717314466834,"fBorderSize":1,"fBorderMode":0},{"_typename":"THStack","fUniqueID":0,"fBits":8,"fName":"s","fTitle":"MC_{rec} vs Data [k_{0}>=1, Z=4];tan(#theta);Entries\/N_{trk}","fHists":{"_typename":"TList","name":"TList","arr":[{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"o4","fTitle":"s[0].Theta() {Z==4}","fLineColor":430,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":52,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":50,"fXmin":0,"fXmax":0.2,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":788,"fTsumw":0.0289937680498556,"fTsumw2":1.10175437185954e-6,"fTsumwx":0.00190226566549191,"fTsumwx2":1.72377807741796e-4,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,2.88795379255449e-9,1.44397689627724e-8,2.59915841329904e-8,3.60994224069311e-8,4.04313530957629e-8,3.46554455106539e-8,3.75433993032084e-8,6.20910065399215e-8,5.19831682659808e-8,3.32114686143766e-8,5.48711220585353e-8,3.89873761994856e-8,4.90952144734263e-8,3.75433993032084e-8,5 ...
