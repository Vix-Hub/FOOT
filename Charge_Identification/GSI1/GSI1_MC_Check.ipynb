# %% [markdown]
# # Import

# %%
import ROOT as r
import fedrarootlogon 
from matplotlib import pyplot as plt
import matplotlib
import awkward as ak
import uproot
import numpy as np
import time

import sys
sys.path.insert(0, "/home/vincenzo/Documents/Vincenzo_FOOT/")
from Clustering_Cosmici_Frammenti import *

def g_func(x, p1, p2, p3):
    return p1* np.exp(- (x - p2)**2 / (2*p3**2) )

# %jsroot on 
track_name = "b000001.2.0.0.trk.root"
file_name = "~/Documents/Vincenzo_FOOT/b11_MC.root"
brick_id = "GSI1"
# Out:
# Welcome to JupyROOT 6.24/06
# Load FEDRA libs

# %% [markdown]
# # Calcolo Variabili di Volume

# %%
#Calcolo_Variabili_Volume_MC(file_name, track_name)

# %% [markdown]
# # Taglio su k0, Plot VR0 vs tan

# %% [markdown]
# ### Analisi per k0

# %%
file = r.TFile(file_name, "READ")
tracks_V = file.Get("tracks_n")

c = r.TCanvas()
tracks_V.Draw("k0", "npl>=32")
t1 = r.TText(c.GetUxmax()/2, 500, brick_id)
t1.SetTextColor(1)
t1.SetTextSize(20)
t1.Draw("SAME")
c.Draw()
# Out:
# <div id="root_plot_1664433822610"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664433822610(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":2.12499993480742,"fY1":-520.668788792847,"fX2":10.8750000651926,"fY2":4686.01878879285,"fXtoAbsPixelk":-169.028513724245,"fXtoPixelk":-169.028513724245,"fXtoPixel":79.5428559575762,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.0906526448853809,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":2.12499993480742,"fPixeltoXk":2.12499993480742,"fPixeltoX":0.0125718392677948,"fAbsPixeltoYk":4686.01878879285,"fPixeltoYk":-520.668788792847,"fPixeltoY":-11.0311177491222,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":3,"fUymin":0,"fUxmax":10,"fUymax":4165.35,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":3,"fY1":0,"fX2":10,"fY2":4165.35,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":9,"fName":"htemp","fTitle":"k0 {npl>=32}","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":9,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":4194304,"fName":"xaxis","fTitle":"k0","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":7,"fXmin":3,"fXmax":10,"fXbins":[],"fFirst":1,"fLast":100,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":10163,"fTsumw":10163,"fTsumw2":10163,"fTsumwx":82335,"fTsumwx2":675137,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":8.95000017732382,"fY1":3514.51411487034,"fX2":10.7000002294779,"fY2":4347.58410866349,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC","fName":"stats","fTextAngle":0,"fTextSize":0,"fTextAlign":12,"fTextColor":1,"fTextFont ...

# %%
file = r.TFile(file_name, "READ")
tracks_V = file.Get("tracks_n")

c = r.TCanvas()
tracks_V.Draw("k1", "npl>=32")
t1 = r.TText(c.GetUxmax()/2, 500, brick_id)
t1.SetTextColor(1)
t1.SetTextSize(20)
t1.Draw("SAME")
c.Draw()

# %%
c = r.TCanvas()

tracks_V.Draw("tanf>>Z1(100, 0, 1)", "s[0].W()-70 == 1 && k0>=4")
hs = r.THStack("h4s", "")
h1 = r.gDirectory.Get("Z1")
hs.Add(h1)

tracks_V.Draw("tanf>>Z2(100, 0, 1)", "s[0].W()-70 == 2 && k0>=4")
h2 = r.gDirectory.Get("Z2")
hs.Add(h2)

tracks_V.Draw("tanf>>Z3(100, 0, 1)", "s[0].W()-70 == 3 && k0>=4")
h3 = r.gDirectory.Get("Z3")
hs.Add(h3)

tracks_V.Draw("tanf>>Z4(100, 0, 1)", "s[0].W()-70 == 4 && k0>=4")
h4 = r.gDirectory.Get("Z4")
hs.Add(h4)

# %%
c = r.TCanvas()
h4.Draw()
c.Draw()

# %%
hs.SetTitle("Fragments Angular Distribution GSI3 MC_{rec} (k_{0}>=4); tan(#theta); Entries")
hs.Draw("pfc nostack")

legend = r.TLegend(0.55,0.6,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(0.1)

def lazy(histo, N):
    return "Entries = "+str(histo.GetEntries()) + " (" + str(round(100*histo.GetEntries()/N, 1)) + "%)}{Mean: "+ str(round(histo.GetMean(), 2)) + ", RMS = "+str(round(histo.GetRMS(),2))+"}"

legend.AddEntry(h1, "#splitline{Z=1, " + lazy(h1, 70965))
legend.AddEntry(h2, "#splitline{Z=2, "+ lazy(h2, 70965))
legend.AddEntry(h3, "#splitline{Z=3, "+ lazy(h3, 70965))
legend.AddEntry(h4, "#splitline{Z==4, "+ lazy(h4, 70965))
legend.Draw("SAME")

c.Draw()

# %%
c = r.TCanvas()

tracks_V.Draw("tanf>>Z1(100, 0, 1)", "s[0].W()-70 == 1 && k0>=3")
hs = r.THStack("h4s", "")
h1 = r.gDirectory.Get("Z1")
hs.Add(h1)

tracks_V.Draw("tanf>>Z2(100, 0, 1)", "s[0].W()-70 == 2 && k0>=3")
h2 = r.gDirectory.Get("Z2")
hs.Add(h2)

tracks_V.Draw("tanf>>Z3(100, 0, 1)", "s[0].W()-70 == 3 && k0>=3")
h3 = r.gDirectory.Get("Z3")
hs.Add(h3)

tracks_V.Draw("tanf>>Z4(100, 0, 1)", "s[0].W()-70 == 4 && k0>=3")
h4 = r.gDirectory.Get("Z4")
hs.Add(h4)

# %%
hs.SetTitle("Fragments Angular Distribution GSI3 MC (k_{0}>=3); tan(#theta); Entries")
hs.Draw("pfc nostack")

legend = r.TLegend(0.55,0.6,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(0.1)

def lazy(histo):
    return "Entries = "+str(histo.GetEntries())+"}{Mean: "+ str(round(histo.GetMean(), 2)) + ", RMS = "+str(round(histo.GetRMS(),2))+"}"

legend.AddEntry(h1, "#splitline{Z=1, " + lazy(h1))
legend.AddEntry(h2, "#splitline{Z=2, "+ lazy(h2))
legend.AddEntry(h3, "#splitline{Z=3, "+ lazy(h3))
legend.AddEntry(h4, "#splitline{Z==4, "+ lazy(h4))
legend.Draw("SAME")

c.Draw()

# %%
c = r.TCanvas()
tracks_V.Draw("tan", "s[0].W()-70 == 8")
c.Draw()

# %%
c = r.TCanvas()
tracks_V.Draw("tan", "s[0].W()-70 == 1 && tan<1 ")
c.Draw()

# %%
c = r.TCanvas()
tracks_V.Draw("sf.P()", "s[0].W()-70 == 1 && tan<1")
c.Draw()

# %% [markdown]
# ## Controlli

# %%
c = r.TCanvas()

tracks_V.Draw("tanf>>Z1(100, 0, 1)", "s[0].W()-70 == 1 && k0>=4")
hs = r.THStack("h4s", "")
h1 = r.gDirectory.Get("Z1")
hs.Add(h1)

tracks_V.Draw("tanf>>Z2(100, 0, 1)", "s[0].W()-70 == 2 && k0>=4")
h2 = r.gDirectory.Get("Z2")
hs.Add(h2)

tracks_V.Draw("tanf>>Z3(100, 0, 1)", "s[0].W()-70 == 3 && k0>=4")
h3 = r.gDirectory.Get("Z3")
hs.Add(h3)

tracks_V.Draw("tanf>>Z4(100, 0, 1)", "s[0].W()-70 == 4 && k0>=4")
h4 = r.gDirectory.Get("Z4")
hs.Add(h4)

tracks_V.Draw("tanf>>Z5(100, 0, 1)", "s[0].W()-70 == 5 && k0>=4")
h5 = r.gDirectory.Get("Z5")
hs.Add(h5)

tracks_V.Draw("tanf>>Z6(100, 0, 1)", "s[0].W()-70 == 6 && k0>=4")
h6 = r.gDirectory.Get("Z6")
hs.Add(h6)

tracks_V.Draw("tanf>>Z7(100, 0, 1)", "s[0].W()-70 == 7 && k0>=4")
h7 = r.gDirectory.Get("Z7")
hs.Add(h7)

tracks_V.Draw("tanf>>Z8(100, 0, 1)", "s[0].W()-70 == 8 && k0>=4")
h8 = r.gDirectory.Get("Z8")
#hs.Add(h8)

# %%
hs.SetTitle("Fragments Angular Distribution GSI3 MC_{rec} (k_{0}>=4); tan(#theta); Entries")
hs.Draw("pfc nostack")

legend = r.TLegend(0.55,0.6,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(0.1)

N = h1.GetEntries() + h2.GetEntries() + h3.GetEntries() + h4.GetEntries()
N = N + h5.GetEntries() + h6.GetEntries() + h7.GetEntries() + h8.GetEntries()

def lazy(histo, N):
    return "Entries = "+str(histo.GetEntries()) + " (" + str(round(100*histo.GetEntries()/N, 1)) + "%)}{Mean: "+ str(round(histo.GetMean(), 2)) + ", RMS = "+str(round(histo.GetRMS(),2))+"}"

legend.AddEntry(h1, "#splitline{Z=1, " + lazy(h1, N))
legend.AddEntry(h2, "#splitline{Z=2, "+ lazy(h2, N))
legend.AddEntry(h3, "#splitline{Z=3, "+ lazy(h3, N))
legend.AddEntry(h4, "#splitline{Z=4, "+ lazy(h4, N))
legend.AddEntry(h5, "#splitline{Z=5, " + lazy(h5, N))
legend.AddEntry(h6, "#splitline{Z=6, "+ lazy(h6, N))
legend.AddEntry(h7, "#splitline{Z=7, "+ lazy(h7, N))
#legend.AddEntry(h8, "#splitline{Z=8, "+ lazy(h8, N))
legend.Draw("SAME")

c.Draw()

# %%
print(N)

# %%
c = r.TCanvas()
h2.SetTitle("Z = 2 Angular Distribution (MC_{rec});tan(#theta);Entries")
h2.SetFillColor(0)
h2.SetLineColor(4)
h2.SetLineWidth(2)
h2.Draw()
c.Draw()

# %%
c = r.TCanvas()
h2.SetTitle("Z = 2 Angular Distribution (MC_{rec});tan(#theta);Entries")
h2.Scale(1./h2.GetEntries())
h2.Draw()
c.Draw()

# %%
c = r.TCanvas()

tracks_V.Draw("tanf>>Z1(100, 0, 1)", "s[0].W()-70 == 1 && k0>=1")
hs = r.THStack("h4s", "")
h1 = r.gDirectory.Get("Z1")
hs.Add(h1)

tracks_V.Draw("tanf>>Z2(100, 0, 1)", "s[0].W()-70 == 2 && k0>=1")
h2 = r.gDirectory.Get("Z2")
hs.Add(h2)

tracks_V.Draw("tanf>>Z3(100, 0, 1)", "s[0].W()-70 == 3 && k0>=1")
h3 = r.gDirectory.Get("Z3")
hs.Add(h3)

tracks_V.Draw("tanf>>Z4(100, 0, 1)", "s[0].W()-70 == 4 && k0>=1")
h4 = r.gDirectory.Get("Z4")
hs.Add(h4)

tracks_V.Draw("tanf>>Z5(100, 0, 1)", "s[0].W()-70 == 5 && k0>=1")
h5 = r.gDirectory.Get("Z5")
hs.Add(h5)

tracks_V.Draw("tanf>>Z6(100, 0, 1)", "s[0].W()-70 == 6 && k0>=1")
h6 = r.gDirectory.Get("Z6")
hs.Add(h6)

tracks_V.Draw("tanf>>Z7(100, 0, 1)", "s[0].W()-70 == 7 && k0>=1")
h7 = r.gDirectory.Get("Z7")
hs.Add(h7)

tracks_V.Draw("tanf>>Z8(100, 0, 1)", "s[0].W()-70 == 8 && k0>=1")
h8 = r.gDirectory.Get("Z8")
hs.Add(h8)

# %%
hs.SetTitle("Fragments Angular Distribution GSI3 MC_{rec} (k_{0}>=1); tan(#theta); Entries")
hs.Draw("pfc nostack")

legend = r.TLegend(0.55,0.6,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(0.1)

N = h1.GetEntries() + h2.GetEntries() + h3.GetEntries() + h4.GetEntries()
N = N + h5.GetEntries() + h6.GetEntries() + h7.GetEntries() + h8.GetEntries()

def lazy(histo, N):
    return "Entries = "+str(histo.GetEntries()) + " (" + str(round(100*histo.GetEntries()/N, 1)) + "%)}{Mean: "+ str(round(histo.GetMean(), 2)) + ", RMS = "+str(round(histo.GetRMS(),2))+"}"

legend.AddEntry(h1, "#splitline{Z=1, " + lazy(h1, N))
legend.AddEntry(h2, "#splitline{Z=2, "+ lazy(h2, N))
legend.AddEntry(h3, "#splitline{Z=3, "+ lazy(h3, N))
legend.AddEntry(h4, "#splitline{Z=4, "+ lazy(h4, N))
legend.AddEntry(h5, "#splitline{Z=5, " + lazy(h5, N))
legend.AddEntry(h6, "#splitline{Z=6, "+ lazy(h6, N))
legend.AddEntry(h7, "#splitline{Z=7, "+ lazy(h7, N))
legend.AddEntry(h8, "#splitline{Z=8, "+ lazy(h8, N))
legend.Draw("SAME")

c.Draw()

# %%
c = r.TCanvas()

tracks_V.Draw("tanf>>Z1(100, 0, 1)", "s[0].W()-70 == 1 && k0>=4")
hs = r.THStack("h4s", "")
h1 = r.gDirectory.Get("Z1")
hs.Add(h1)

tracks_V.Draw("tanf>>Z2(100, 0, 1)", "s[0].W()-70 == 2 && k0>=4")
h2 = r.gDirectory.Get("Z2")
hs.Add(h2)

tracks_V.Draw("tanf>>Z3(100, 0, 1)", "s[0].W()-70 == 3 && k0>=4")
h3 = r.gDirectory.Get("Z3")
hs.Add(h3)

tracks_V.Draw("tanf>>Z4(100, 0, 1)", "s[0].W()-70 == 4 && k0>=4")
h4 = r.gDirectory.Get("Z4")
hs.Add(h4)

tracks_V.Draw("tanf>>Z5(100, 0, 1)", "s[0].W()-70 == 5 && k0>=4")
h5 = r.gDirectory.Get("Z5")
hs.Add(h5)

tracks_V.Draw("tanf>>Z6(100, 0, 1)", "s[0].W()-70 == 6 && k0>=4")
h6 = r.gDirectory.Get("Z6")
hs.Add(h6)

tracks_V.Draw("tanf>>Z7(100, 0, 1)", "s[0].W()-70 == 7 && k0>=4")
h7 = r.gDirectory.Get("Z7")
hs.Add(h7)

tracks_V.Draw("tanf>>Z8(100, 0, 1)", "s[0].W()-70 == 8 && k0>=4")
h8 = r.gDirectory.Get("Z8")
hs.Add(h8)

# %%
hs.SetTitle("Fragments Angular Distribution GSI3 MC_{rec} (k_{0}>=4); tan(#theta); Entries")
hs.Draw("pfc nostack")

legend = r.TLegend(0.55,0.6,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(0.1)

N = h1.GetEntries() + h2.GetEntries() + h3.GetEntries() + h4.GetEntries()
N = N + h5.GetEntries() + h6.GetEntries() + h7.GetEntries() + h8.GetEntries()

def lazy(histo, N):
    return "Entries = "+str(histo.GetEntries()) + " (" + str(round(100*histo.GetEntries()/N, 1)) + "%)}{Mean: "+ str(round(histo.GetMean(), 2)) + ", RMS = "+str(round(histo.GetRMS(),2))+"}"

legend.AddEntry(h1, "#splitline{Z=1, " + lazy(h1, N))
legend.AddEntry(h2, "#splitline{Z=2, "+ lazy(h2, N))
legend.AddEntry(h3, "#splitline{Z=3, "+ lazy(h3, N))
legend.AddEntry(h4, "#splitline{Z=4, "+ lazy(h4, N))
legend.AddEntry(h5, "#splitline{Z=5, " + lazy(h5, N))
legend.AddEntry(h6, "#splitline{Z=6, "+ lazy(h6, N))
legend.AddEntry(h7, "#splitline{Z=7, "+ lazy(h7, N))
legend.AddEntry(h8, "#splitline{Z=8, "+ lazy(h8, N))
legend.Draw("SAME")

c.Draw()

# %%
N

# %% [markdown]
# # Confronti con Output

# %%
out_name = "output_cuts_GSI1.root"
file_out = r.TFile(out_name, "READ")

out_tree = file_out.Get("tracks")

out_tree.Draw("s[0].Theta()>>o1(100,0,1)", "Z==1")
o1 = r.gDirectory.Get("o1")

c = r.TCanvas()
#o1.Scale(1/o1.Integral())
o1.Draw()
o1.Sumw2()
c.Draw()
# Out:
# Warning in <TFile::Init>: file output_cuts_GSI1.root probably not closed, trying to recover
# Info in <TFile::Recover>: output_cuts_GSI1.root, recovered key TTree:tracks at address 186134979
# Info in <TFile::Recover>: output_cuts_GSI1.root, recovered key TTree:output_tree at address 196934027
# Warning in <TFile::Init>: successfully recovered 2 keys
# <div id="root_plot_1664433827122"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664433827122(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.125000009313226,"fY1":-69.0965603401793,"fX2":1.12500000931323,"fY2":621.869001876855,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":556.799991703033,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-0.683102061534788,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.125000009313226,"fPixeltoXk":-0.125000009313226,"fPixeltoX":0.0017959770382564,"fAbsPixeltoYk":621.869001876855,"fPixeltoYk":-69.0965603401793,"fPixeltoY":-1.46391008944287,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":552.772441536676,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":1,"fY2":552.772441536676,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"o1","fTitle":"s[0].Theta() {Z==1}","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":22360,"fTsumw":22301,"fTsumw2":22301,"fTsumwx":8228.29834549571,"fTsumwx2":4431.06511772332,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,38,84,166,223,241,290,349,386,383,443,425,476,450,498,504,490,494,462,406,410,447,402,387,408,372,379,322,354,327,320,312,324,330,301,290,301,254,273,263,249,239,200,208,252,217,201,191,194,179,194,212,207,197,169,158,168,174,181,171,161,156,182,159,157,167,172,154,138,143,133,158,123,110,125,132,116,127,122,131,116,100,109,97,102,128,112,85,94,97,103,106,107,72,99,72,70,57,76,60,28,59],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":9,"fLineColor":1," ...

# %%
out_tree.Draw("nseg>>Z5(50)", "Z>0 && Z<7")
h4 = r.gDirectory.Get("Z5")
N2 = h4.GetEntries()
print(N2)


tracks_V.Draw("tanf>>N(100, 0, 1)", "s[0].W()-70 > 0 && k0>=1")
h8 = r.gDirectory.Get("N")
N = h8.GetEntries()
print(N)
# Out:
# 33058.0
# 27709.0

# %%
h1.SetFillColor(0)
h1.SetLineColor(2)
h1.SetLineWidth(2)
h1.Sumw2(r.kFALSE)

o1.SetFillColor(0)
o1.SetLineColor(4)
o1.SetLineWidth(2)
o1.Sumw2(r.kFALSE)

h1.Scale(1/N)
o1.Scale(1/N2)

s1 = r.THStack("s1", "s1")
s1.Add(o1)
s1.Add(h1)
c = r.TCanvas()
s1.SetTitle("MC_{rec} vs Data [k_{0}>=1, Z=1];tan(#theta);Entries/N_{trk}")
s1.Draw("nostack")

legend = r.TLegend(0.45,0.65,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(1.)
legend.AddEntry(h1, "#splitline{Z=1 (MC_{rec}), Entries = "+str(round(h1.GetEntries(),0))+" ("+str(round(100*h1.GetEntries()/N, 1) ) + " %)}{Mean: "+ str(round(h1.GetMean(), 2)) + ", RMS = "+str(round(h1.GetRMS(),2))+"}")
legend.AddEntry(o1, "#splitline{Z=1 (Data), Entries = "+str(round(o1.GetEntries(),0))+" ("+str(round(100*o1.GetEntries()/N2, 1) ) + " %)}{Mean: "+ str(round(o1.GetMean(), 2)) + ", RMS = "+str(round(o1.GetRMS(),2))+"}")

legend.Draw("SAME")

c.Draw()

# %%
N

# %%
h1.Scale(1/N)
o1.Scale(1/N2)

# %%
c = r.TCanvas()
#o1.Draw()
h1.Draw("SAME")
c.Draw()

# %%
c = r.TCanvas()
o1.Draw()
#h1.Draw("SAME")
c.Draw()

# %%
h1.SetFillColor(0)
h1.SetLineColor(2)
h1.SetLineWidth(2)
h1.Sumw2(r.kFALSE)

o1.SetFillColor(0)
o1.SetLineColor(4)
o1.SetLineWidth(2)
o1.Sumw2(r.kFALSE)

s1 = r.THStack("s1", "s1")
s1.Add(o1)
s1.Add(h1)
c = r.TCanvas()
s1.SetTitle("MC_{rec} vs Data [k_{0}>=4, Z=1];tan(#theta);Entries/N_{trk}")
s1.Draw("nostack")

legend = r.TLegend(0.45,0.65,0.9,0.9)
legend.SetTextFont(0)
legend.SetTextSize(1.)
legend.AddEntry(h1, "#splitline{Z=1 (MC_{rec}), Entries = "+str(round(h1.GetEntries(),0))+"}{Mean: "+ str(round(h1.GetMean(), 2)) + ", RMS = "+str(round(h1.GetRMS(),2))+"}")
legend.AddEntry(o1, "#splitline{Z=1 (Data), Entries = "+str(round(o1.GetEntries(),0))+"}{Mean: "+ str(round(o1.GetMean(), 2)) + ", RMS = "+str(round(o1.GetRMS(),2))+"}")

legend.Draw("SAME")

c.Draw()

# %%
N

# %%
def CompareMC2(Z, N, N2):
    
    if (Z!=6 and Z!=5 and Z!=4):
        out_tree.Draw("s[0].Theta()>>o"+str(Z)+"(50,0,1)", "Z=="+str(Z))
    elif (Z==6):
        out_tree.Draw("s[0].Theta()>>o"+str(Z)+"(50,0,0.1)", "Z=="+str(Z))
    elif (Z==5):
        out_tree.Draw("s[0].Theta()>>o"+str(Z)+"(50,0,0.2)", "Z=="+str(Z))
    elif (Z==4):
        out_tree.Draw("s[0].Theta()>>o"+str(Z)+"(50,0,0.2)", "Z=="+str(Z))
    o = r.gDirectory.Get("o"+str(Z))
    o.Scale(1/N2)
    o.Sumw2()
    
    if (Z!=6 and Z!=5 and Z!=4):
        print("tanf>>Z_"+str(Z)+"(100, 0, 1)", "s[0].W()-70 == "+str(Z)+" && k0>=4")
        tracks_V.Draw("s[0].Theta()>>Z_"+str(Z)+"(50, 0, 1)", "s[0].W()-70 == "+str(Z)+" && k0>=1")
    elif (Z == 6):
        tracks_V.Draw("s[0].Theta()>>Z_"+str(Z)+"(50, 0, 0.1)", "s[0].W()-70 >= "+str(Z)+" && s[0].W()-70<9 && k0>=1")
    elif (Z == 5):
        tracks_V.Draw("s[0].Theta()>>Z_"+str(Z)+"(50, 0, 0.2)", "s[0].W()-70 == "+str(Z)+" && s[0].W()-70<9 && k0>=1")
    elif (Z == 4):
        tracks_V.Draw("s[0].Theta()>>Z_"+str(Z)+"(50, 0, 0.2)", "s[0].W()-70 >= "+str(Z)+" && s[0].W()-70<9 && k0>=1")
    h = r.gDirectory.Get("Z_"+str(Z))
    h.Scale(1/N)
    h.Sumw2(r.kFALSE)
    
    h.SetFillColor(0)
    h.SetLineColor(r.kBlue)
    
    h.SetLineWidth(2)
    h.SetLineStyle(2)

    o.SetFillColor(0)
    o.SetLineColor(r.kCyan-2)
    o.SetLineWidth(2)
    
    s = r.THStack("s", "s")
    s.Add(o)
    s.Add(h)
    
    s.SetTitle("MC_{rec} vs Data [k_{0}>=1, Z="+str(Z)+"];tan(#theta);Entries/N_{trk}")
    #s.Draw("nostack")

    legend = r.TLegend(0.45,0.65,0.9,0.9)
    legend.SetTextFont(0)
    legend.SetTextSize(1.)
    legend.AddEntry(h, "#splitline{Z="+str(Z)+" (MC_{rec}), Entries = "+str(round(h.GetEntries(),0))+" ("+str(round(100*h.GetEntries()/N, 1) ) + " %)}{Mean: "+ str(round(h.GetMean(), 2)) + ", RMS = "+str(round(h.GetRMS(),2))+"}")
    legend.AddEntry(o, "#splitline{Z="+str(Z)+ " (Data), Entries = "+str(round(o.GetEntries(),0))+" ("+str(round(100*o.GetEntries()/N2, 1) ) + " %)}{Mean: "+ str(round(o.GetMean(), 2)) + ", RMS = "+str(round(o.GetRMS(),2))+"}")

    return s, legend

# %%
s1, leg1 = CompareMC2(1,N,N2)
s2, leg2 = CompareMC2(2,N,N2)
s3, leg3 = CompareMC2(3,N,N2)
s4, leg4 = CompareMC2(4,N,N2)
# Out:
# tanf>>Z_1(100, 0, 1) s[0].W()-70 == 1 && k0>=4
# tanf>>Z_2(100, 0, 1) s[0].W()-70 == 2 && k0>=4
# tanf>>Z_3(100, 0, 1) s[0].W()-70 == 3 && k0>=4
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %%
c = r.TCanvas()
s1.Draw("nostack")
leg1.Draw("SAME")
c.Draw()
# Out:
# <div id="root_plot_1664434040191"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664434040191(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.125000009313226,"fY1":-0.0039464730682949,"fX2":1.12500000931323,"fY2":0.0355182552623729,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":556.799991703033,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-11960.0468561496,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.125000009313226,"fPixeltoXk":-0.125000009313226,"fPixeltoX":0.0017959770382564,"fAbsPixeltoYk":0.0355182552623729,"fPixeltoYk":-0.0039464730682949,"fPixeltoY":-8.36117125649741e-5,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":0.031571782194078,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":1,"fY2":0.031571782194078,"fBorderSize":1,"fBorderMode":0},{"_typename":"THStack","fUniqueID":0,"fBits":8,"fName":"s","fTitle":"MC_{rec} vs Data [k_{0}>=1, Z=1];tan(#theta);Entries\/N_{trk}","fHists":{"_typename":"TList","name":"TList","arr":[{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"o1","fTitle":"s[0].Theta() {Z==1}","fLineColor":430,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":52,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":50,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":22360,"fTsumw":0.674602214290036,"fTsumw2":2.04066251524604e-5,"fTsumwx":0.248904904879173,"fTsumwx2":0.134039116635106,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,1.11636620268157e-7,3.55956108887812e-7,4.85893814445831e-7,6.72564884402421e-7,7.55834822471292e-7,8.24463892308274e-7,8.67471442739449e-7,9.09563938906131e-7,8.74791876855394e-7,7.46684279826361e-7,7.76881070554633e-7,7.27468140272006e-7,6.8720575263431e-7,6.18576682797329e-7,5.92040109127029e-7,5.81 ...

# %%
c = r.TCanvas()
s2.Draw("nostack")
leg2.Draw("SAME")
c.Draw()
# Out:
# <div id="root_plot_1664434040320"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664434040320(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.125000009313226,"fY1":-0.00393622137130956,"fX2":1.12500000931323,"fY2":0.0354259899956153,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":556.799991703033,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-11991.1962160899,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.125000009313226,"fPixeltoXk":-0.125000009313226,"fPixeltoX":0.0017959770382564,"fAbsPixeltoYk":0.0354259899956153,"fPixeltoYk":-0.00393622137130956,"fPixeltoY":-8.33945156078916e-5,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":0.0314897686243057,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":1,"fY2":0.0314897686243057,"fBorderSize":1,"fBorderMode":0},{"_typename":"THStack","fUniqueID":0,"fBits":8,"fName":"s","fTitle":"MC_{rec} vs Data [k_{0}>=1, Z=2];tan(#theta);Entries\/N_{trk}","fHists":{"_typename":"TList","name":"TList","arr":[{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"o2","fTitle":"s[0].Theta() {Z==2}","fLineColor":430,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":52,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":50,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":6714,"fTsumw":0.20297658660536,"fTsumw2":6.14001411474863e-6,"fTsumwx":0.0393045217902851,"fTsumwx2":0.0139559795502731,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,1.41833410996429e-7,4.30075504311752e-7,5.55437938547305e-7,5.60013209869771e-7,5.92040109127029e-7,5.13345442380623e-7,4.23670124460301e-7,3.33994806539978e-7,2.69025953760968e-7,2.61705519645024e-7,2.21443132007328e-7,2.08632372304424e-7,1.72945255989194e-7,1.34512976880484e-7,1.29937705558019e-7 ...

# %%
c = r.TCanvas()
s3.Draw("nostack")
leg3.Draw("SAME")
c.Draw()
# Out:
# <div id="root_plot_1664434040431"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664434040431(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.125000009313226,"fY1":-0.00144121700110599,"fX2":1.12500000931323,"fY2":0.0129709521509217,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":556.799991703033,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-32750.1013220896,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.125000009313226,"fPixeltoXk":-0.125000009313226,"fPixeltoX":0.0017959770382564,"fAbsPixeltoYk":0.0129709521509217,"fPixeltoYk":-0.00144121700110599,"fPixeltoY":-3.05342566780247e-5,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":0.0115297351498157,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":1,"fY2":0.0115297351498157,"fBorderSize":1,"fBorderMode":0},{"_typename":"THStack","fUniqueID":0,"fBits":8,"fName":"s","fTitle":"MC_{rec} vs Data [k_{0}>=1, Z=3];tan(#theta);Entries\/N_{trk}","fHists":{"_typename":"TList","name":"TList","arr":[{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"o3","fTitle":"s[0].Theta() {Z==3}","fLineColor":430,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":52,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":50,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":2960,"fTsumw":0.0895395970718132,"fTsumw2":2.70856062289955e-6,"fTsumwx":0.0114097425184804,"fTsumwx2":0.00249082233200418,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,1.16211891590622e-7,3.06543178605185e-7,3.18438884043595e-7,3.32164698010992e-7,2.69025953760968e-7,2.55300139793572e-7,2.02226992452973e-7,1.90331287014563e-7,1.45493628054401e-7,1.23532325706567e-7,8.05247752753919e-8,6.22236899855301e-8,5.21580930761061e-8,4.66677674891476e-8,3.47720620507374 ...

# %%
c = r.TCanvas()
s4.Draw("nostack")
leg4.Draw("SAME")
c.Draw()
# Out:
# <div id="root_plot_1664434040544"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1664434040544(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.0250000018626453,"fY1":-4.21568829310598e-4,"fX2":0.225000001862645,"fY2":0.00379411921252078,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":2783.99995851517,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-111962.74376008,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-0.0250000018626453,"fPixeltoXk":-0.0250000018626453,"fPixeltoX":3.59195407651279e-4,"fAbsPixeltoYk":0.00379411921252078,"fPixeltoYk":-4.21568829310598e-4,"fPixeltoY":-8.93154246150716e-6,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":0.2,"fUymax":0.00337255038321018,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":0.2,"fY2":0.00337255038321018,"fBorderSize":1,"fBorderMode":0},{"_typename":"THStack","fUniqueID":0,"fBits":8,"fName":"s","fTitle":"MC_{rec} vs Data [k_{0}>=1, Z=4];tan(#theta);Entries\/N_{trk}","fHists":{"_typename":"TList","name":"TList","arr":[{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"o4","fTitle":"s[0].Theta() {Z==4}","fLineColor":430,"fLineStyle":1,"fLineWidth":2,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":52,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":50,"fXmin":0,"fXmax":0.2,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":1024,"fTsumw":0.0306128622421199,"fTsumw2":9.26034915667007e-7,"fTsumwx":0.00192755464563184,"fTsumwx2":1.68124659883757e-4,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,3.66021705797236e-9,1.28107597029033e-8,1.46408682318894e-8,2.37914108768203e-8,3.66021705797236e-8,2.83666821992858e-8,3.84322791087098e-8,5.58183101340785e-8,4.39226046956683e-8,3.93473333732029e-8,5.21580930761061e-8,4.20924961666821e-8,4.94129302826268e-8,3.84322791087098e-8,3 ...
